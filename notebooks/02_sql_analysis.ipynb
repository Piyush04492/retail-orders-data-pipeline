# %% [markdown]
# # 02 SQL Analysis Notebook
# This notebook loads the 14 SQL queries from individual `.sql` files in the `sql/` directory and executes them dynamically.

# %%
import os
import sys
sys.path.append(os.path.abspath('..'))

import pandas as pd
from src.database import get_db_engine
from src.config import SQL_DIR

engine = get_db_engine()

# %%
def run_query(filename):
    sql_file_path = os.path.join(SQL_DIR, filename)
    with open(sql_file_path, 'r') as f:
        query = f.read()
    return pd.read_sql(query, engine)

# %% [markdown]
# ### Query 1: Top 10 Products by Sales

# %%
run_query("top_products.sql")
# Out:
#         product_id    sales
# 0  TEC-CO-10004722  59514.0
# 1  OFF-BI-10003527  26525.3
# 2  TEC-MA-10002412  21734.4
# 3  FUR-CH-10002024  21096.2
# 4  OFF-BI-10001359  19090.2
# 5  OFF-BI-10000545  18249.0
# 6  TEC-CO-10001449  18151.2
# 7  TEC-MA-10001127  17906.4
# 8  OFF-BI-10004995  17354.8
# 9  OFF-SU-10000151  16325.8

# %% [markdown]
# ### Query 2: Top 5 Selling Products in Each Region

# %%
run_query("top_products_by_region.sql")
# Out:
#      region       product_id    sales  rn
# 0   Central  TEC-CO-10004722  16975.0   1
# 1   Central  TEC-MA-10000822  13770.0   2
# 2   Central  OFF-BI-10001120  11056.5   3
# 3   Central  OFF-BI-10000545  10132.7   4
# 4   Central  OFF-BI-10004995   8416.1   5
# 5      East  TEC-CO-10004722  29099.0   1
# 6      East  TEC-MA-10001047  13767.0   2
# 7      East  FUR-BO-10004834  11274.1   3
# 8      East  OFF-BI-10001359   8463.6   4
# 9      East  TEC-CO-10001449   8316.0   5
# 10    South  TEC-MA-10002412  21734.4   1
# 11    South  TEC-MA-10001127  11116.4   2
# 12    South  OFF-BI-10001359   8053.2   3
# 13    South  TEC-MA-10004125   7840.0   4
# 14    South  OFF-BI-10003527   7391.4   5
# 15     West  TEC-CO-10004722  13440.0   1
# 16     West  OFF-SU-10000151  12592.3   2
# 17     West  FUR-CH-10001215   9604.0   3
# 18     West  OFF-BI-10003527   7804.8   4
# 19     West  TEC-AC-10003832   7722.7   5

# %% [markdown]
# ### Query 3: Month-over-Month Sales Comparison (2022 vs 2023)

# %%
run_query("monthly_sales.sql")
# Out:
#     order_month  sales_2022  sales_2023
# 0             1     94712.5     88632.6
# 1             2     90091.0    128124.2
# 2             3     80106.0     82512.3
# 3             4     95451.6    111568.6
# 4             5     79448.3     86447.9
# 5             6     94170.5     68976.5
# 6             7     78652.2     90563.8
# 7             8    104808.0     87733.6
# 8             9     79142.2     76658.6
# 9            10    118912.7    121061.5
# 10           11     84225.3     75432.8
# 11           12     95869.9    102556.1

# %% [markdown]
# ### Query 4: Best Selling Month by Category

# %%
run_query("best_selling_month.sql")
# Out:
#           category order_year_month    sales  rn
# 0        Furniture           202210  42888.9   1
# 1  Office Supplies           202302  44118.5   1
# 2       Technology           202310  53000.1   1

# %% [markdown]
# ### Query 5: Sub-Category with Highest YoY Sales Growth

# %%
run_query("yoy_growth.sql")
# Out:
#   sub_category  sales_2022  sales_2023   growth
# 0     Machines     73723.2    109178.5  35455.3

# %% [markdown]
# ### Query 6: Top 10 States by Sales

# %%
run_query("state_sales.sql")
# Out:
#           state  total_sales
# 0    California     441657.0
# 1      New York     299597.5
# 2         Texas     164276.9
# 3    Washington     133779.7
# 4  Pennsylvania     112417.4
# 5       Florida      86071.1
# 6      Illinois      77164.8
# 7          Ohio      75531.4
# 8      Michigan      73519.5
# 9      Virginia      68298.5

# %% [markdown]
# ### Query 7: Average Profit by Category

# %%
run_query("category_avg_profit.sql")
# Out:
#           category  avg_profit
# 0       Technology       41.38
# 1        Furniture       31.34
# 2  Office Supplies       10.33

# %% [markdown]
# ### Query 8: Ship Mode Orders Count

# %%
run_query("ship_mode_orders.sql")
# Out:
#         ship_mode  total_orders
# 0  Standard Class          5962
# 1    Second Class          1945
# 2     First Class          1538
# 3        Same Day           543
# 4             NaN             6

# %% [markdown]
# ### Query 9: Top 10 Cities by Profit

# %%
run_query("city_profit.sql")
# Out:
#             city  total_profit
# 0  New York City       20925.7
# 1    Los Angeles       15088.4
# 2  San Francisco       10140.1
# 3        Seattle        9828.7
# 4   Philadelphia        9788.3
# 5        Houston        6029.4
# 6   Jacksonville        5198.6
# 7        Chicago        4203.4
# 8      San Diego        4041.9
# 9    Springfield        3775.5

# %% [markdown]
# ### Query 10: Quantity Sold by Category

# %%
run_query("category_sales.sql")
# Out:
#           category  total_quantity
# 0  Office Supplies         22906.0
# 1        Furniture          8028.0
# 2       Technology          6939.0

# %% [markdown]
# ### Query 11: Top 5 States by Profit

# %%
run_query("state_profit.sql")
# Out:
#           state  total_profit
# 0    California       40207.0
# 1      New York       25557.5
# 2         Texas       14946.9
# 3    Washington       11169.7
# 4  Pennsylvania       10227.4

# %% [markdown]
# ### Query 12: Ship Mode Orders, Sales, and Profit Analysis

# %%
run_query("ship_mode_analysis.sql")
# Out:
#         ship_mode  total_orders  total_sales  total_profit
# 0  Standard Class          5962    1307065.1      122005.1
# 1    Second Class          1945     442976.1       41386.1
# 2     First Class          1538     339242.3       30452.3
# 3        Same Day           543     123747.2       10987.2
# 4             NaN             6       2828.0         338.0

# %% [markdown]
# ### Query 13: Average Discount and Profit by Category

# %%
run_query("category_discount.sql")
# Out:
#           category  avg_discount  avg_profit
# 0       Technology         15.89       41.38
# 1        Furniture         12.28       31.34
# 2  Office Supplies          4.14       10.33

# %% [markdown]
# ### Query 14: Best Selling Product per Category

# %%
run_query("best_selling_product.sql")
# Out:
#           category       product_id  total_sales
# 0        Furniture  FUR-CH-10002024      21096.2
# 1  Office Supplies  OFF-BI-10003527      26525.3
# 2       Technology  TEC-CO-10004722      59514.0
